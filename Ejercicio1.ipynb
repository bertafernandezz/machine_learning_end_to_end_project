# %%
pip install skrub
# Out:
# Collecting skrub
#   Downloading skrub-0.5.3-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: numpy>=1.23.5 in c:\users\marti\anaconda3\lib\site-packages (from skrub) (1.26.4)
# Requirement already satisfied: packaging>=23.1 in c:\users\marti\anaconda3\lib\site-packages (from skrub) (24.1)
# Requirement already satisfied: pandas>=1.5.3 in c:\users\marti\anaconda3\lib\site-packages (from skrub) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.2.1 in c:\users\marti\anaconda3\lib\site-packages (from skrub) (1.5.1)
# Requirement already satisfied: scipy>=1.9.3 in c:\users\marti\anaconda3\lib\site-packages (from skrub) (1.13.1)
# Requirement already satisfied: jinja2>=3.1.2 in c:\users\marti\anaconda3\lib\site-packages (from skrub) (3.1.4)
# Requirement already satisfied: matplotlib>=3.4.3 in c:\users\marti\anaconda3\lib\site-packages (from skrub) (3.9.2)
# Requirement already satisfied: requests>=2.25.0 in c:\users\marti\anaconda3\lib\site-packages (from skrub) (2.32.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\marti\anaconda3\lib\site-packages (from jinja2>=3.1.2->skrub) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\marti\anaconda3\lib\site-packages (from matplotlib>=3.4.3->skrub) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\marti\anaconda3\lib\site-packages (from matplotlib>=3.4.3->skrub) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\marti\anaconda3\lib\site-packages (from matplotlib>=3.4.3->skrub) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\marti\anaconda3\lib\site-packages (from matplotlib>=3.4.3->skrub) (1.4.4)
# Requirement already satisfied: pillow>=8 in c:\users\marti\anaconda3\lib\site-packages (from matplotlib>=3.4.3->skrub) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\marti\anaconda3\lib\site-packages (from matplotlib>=3.4.3->skrub) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\marti\anaconda3\lib\site-packages (from matplotlib>=3.4.3->skrub) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\marti\anaconda3\lib\site-packages (from pandas>=1.5.3->skrub) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\marti\anaconda3\lib\site-packages (from pandas>=1.5.3->skrub) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\marti\anaconda3\lib\site-packages (from requests>=2.25.0->skrub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\marti\anaconda3\lib\site-packages (from requests>=2.25.0->skrub) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\marti\anaconda3\lib\site-packages (from requests>=2.25.0->skrub) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\marti\anaconda3\lib\site-packages (from requests>=2.25.0->skrub) (2024.8.30)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\marti\anaconda3\lib\site-packages (from scikit-learn>=1.2.1->skrub) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\marti\anaconda3\lib\site-packages (from scikit-learn>=1.2.1->skrub) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\marti\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.4.3->skrub) (1.16.0)
# Downloading skrub-0.5.3-py3-none-any.whl (339 kB)
# Installing collected packages: skrub
# Successfully installed skrub-0.5.3
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install feature-engine
# Out:
# Collecting feature-engine
#   Using cached feature_engine-1.8.3-py2.py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: numpy>=1.18.2 in c:\users\marti\anaconda3\lib\site-packages (from feature-engine) (1.26.4)
# Requirement already satisfied: pandas>=2.2.0 in c:\users\marti\anaconda3\lib\site-packages (from feature-engine) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.4.0 in c:\users\marti\anaconda3\lib\site-packages (from feature-engine) (1.5.1)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\marti\anaconda3\lib\site-packages (from feature-engine) (1.13.1)
# Requirement already satisfied: statsmodels>=0.11.1 in c:\users\marti\anaconda3\lib\site-packages (from feature-engine) (0.14.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\marti\anaconda3\lib\site-packages (from pandas>=2.2.0->feature-engine) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\marti\anaconda3\lib\site-packages (from pandas>=2.2.0->feature-engine) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\marti\anaconda3\lib\site-packages (from pandas>=2.2.0->feature-engine) (2023.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\marti\anaconda3\lib\site-packages (from scikit-learn>=1.4.0->feature-engine) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\marti\anaconda3\lib\site-packages (from scikit-learn>=1.4.0->feature-engine) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\marti\anaconda3\lib\site-packages (from statsmodels>=0.11.1->feature-engine) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in c:\users\marti\anaconda3\lib\site-packages (from statsmodels>=0.11.1->feature-engine) (24.1)
# Requirement already satisfied: six in c:\users\marti\anaconda3\lib\site-packages (from patsy>=0.5.6->statsmodels>=0.11.1->feature-engine) (1.16.0)
# Using cached feature_engine-1.8.3-py2.py3-none-any.whl (378 kB)
# Installing collected packages: feature-engine
# Successfully installed feature-engine-1.8.3
# Note: you may need to restart the kernel to use updated packages.

# %%
from utils.transformations import ExtendedTransformation, SimpleTransformation
from utils.filters import SimpleFilter
import pandas as pd
import numpy as np

# %%
df_train = pd.read_csv("data/preprocessed/train_data.csv")
X_train, y_train = df_train.drop(columns=['Price']), df_train[['Price']]
preprocessor = ExtendedTransformation()
filter = SimpleFilter()
preprocessor.fit(X_train, y_train)
X_processed, y_processed = preprocessor.transform(X_train, y_train)
filter.fit(X_processed, y_processed)
X_filtered, y_filtered = filter.transform(X_processed, y_processed)
# Out:
# X shape:  (20974, 40)
# bin_vars_columns shape:  (36,)
# low_card_columns shape:  37
# X shape:  (20974, 40)
# X_low_card   shape:  (20974, 113)
# X_high_card shape:  (20974, 50)
# X_crossed_features shape:  (20974, 6670)
# X_EXPANDED shape:  (20974, 6835)
# (20974, 6835)
# (20974, 4173)
# (20974, 3193)
# (20974, 1635)
# (20974, 4173)
# (20974, 3193)
# (20974, 1635)

# %%
df_test = pd.read_csv("data/preprocessed/test_data.csv")
X_test, y_test = df_test.drop(columns=['Price']), df_test[['Price']]
X_test_proccesed, y_test_proccessed = preprocessor.transform(X_test, y_test)
X_test_filtered, y_test_filtered = filter.transform(X_test_proccesed, y_test_proccessed)
# Out:
# X shape:  (8989, 40)
# X_low_card   shape:  (8989, 113)
# X_high_card shape:  (8989, 50)
# X_crossed_features shape:  (8989, 6670)
# X_EXPANDED shape:  (8989, 6835)
# (8989, 4173)
# (8989, 3193)
# (8989, 1635)

# %%
pip install optuna
# Out:
# Requirement already satisfied: optuna in c:\users\marti\anaconda3\lib\site-packages (4.3.0)
# Requirement already satisfied: alembic>=1.5.0 in c:\users\marti\anaconda3\lib\site-packages (from optuna) (1.15.2)
# Requirement already satisfied: colorlog in c:\users\marti\anaconda3\lib\site-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in c:\users\marti\anaconda3\lib\site-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\marti\anaconda3\lib\site-packages (from optuna) (24.1)
# Requirement already satisfied: sqlalchemy>=1.4.2 in c:\users\marti\anaconda3\lib\site-packages (from optuna) (2.0.34)
# Requirement already satisfied: tqdm in c:\users\marti\anaconda3\lib\site-packages (from optuna) (4.66.5)
# Requirement already satisfied: PyYAML in c:\users\marti\anaconda3\lib\site-packages (from optuna) (6.0.1)
# Requirement already satisfied: Mako in c:\users\marti\anaconda3\lib\site-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in c:\users\marti\anaconda3\lib\site-packages (from alembic>=1.5.0->optuna) (4.13.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\marti\anaconda3\lib\site-packages (from sqlalchemy>=1.4.2->optuna) (3.0.1)
# Requirement already satisfied: colorama in c:\users\marti\anaconda3\lib\site-packages (from colorlog->optuna) (0.4.6)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\marti\anaconda3\lib\site-packages (from Mako->alembic>=1.5.0->optuna) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import optuna
from sklearn.ensemble import GradientBoostingRegressor
import sklearn.model_selection
from sklearn.metrics import mean_pinball_loss, make_scorer

def objective(trial):
    x, y = X_filtered, y_filtered.flatten()

    # Hiperparámetros
    n_estimators = trial.suggest_int("n_estimators", 10, 500, log=True)
    max_depth = trial.suggest_int("max_depth", 5, 32, log=True)
    learning_rate = trial.suggest_float("learning_rate", 0.001, 0.1, log=True)
    min_samples_leaf = trial.suggest_int("min_samples_leaf", 1, 20)
    subsample = trial.suggest_float("subsample", 0.5, 1.0)

    estimator = GradientBoostingRegressor(
        n_estimators=n_estimators,
        max_depth=max_depth,
        learning_rate=learning_rate,
        min_samples_leaf=min_samples_leaf,
        subsample=subsample,
        loss="quantile",
        alpha=0.5
    )

    # Métrica y evaluación
    score = make_scorer(mean_pinball_loss, alpha=0.5)
    scoring = sklearn.model_selection.cross_val_score(
        estimator, x, y, n_jobs=-1, cv=3, scoring=score
    )

    return scoring.mean()

# %%
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=10)

print("Mejores hiperparámetros encontrados:")
print(study.best_trial.params)
# Out:
# [I 2025-05-18 19:16:46,611] A new study created in memory with name: no-name-81a2769c-da48-4845-9428-9fa60547ef79
# [I 2025-05-18 19:20:08,397] Trial 0 finished with value: 0.273765176607571 and parameters: {'n_estimators': 142, 'max_depth': 7, 'learning_rate': 0.019889634195779663, 'min_samples_leaf': 6, 'subsample': 0.9650245722935478}. Best is trial 0 with value: 0.273765176607571.
# [I 2025-05-18 19:20:45,748] Trial 1 finished with value: 0.2876741463752647 and parameters: {'n_estimators': 36, 'max_depth': 8, 'learning_rate': 0.04466793269354801, 'min_samples_leaf': 1, 'subsample': 0.6604823495147313}. Best is trial 0 with value: 0.273765176607571.
# [I 2025-05-18 19:21:23,839] Trial 2 finished with value: 0.33147267567427946 and parameters: {'n_estimators': 16, 'max_depth': 30, 'learning_rate': 0.04176035951902224, 'min_samples_leaf': 4, 'subsample': 0.6199841675632588}. Best is trial 0 with value: 0.273765176607571.
# [I 2025-05-18 19:22:54,247] Trial 3 finished with value: 0.4193380368553071 and parameters: {'n_estimators': 31, 'max_depth': 13, 'learning_rate': 0.0021291084200712115, 'min_samples_leaf': 3, 'subsample': 0.6017758454884508}. Best is trial 0 with value: 0.273765176607571.
# [I 2025-05-18 19:23:53,107] Trial 4 finished with value: 0.29069921022924117 and parameters: {'n_estimators': 35, 'max_depth': 6, 'learning_rate': 0.05406642378378261, 'min_samples_leaf': 18, 'subsample': 0.7850995955116015}. Best is trial 0 with value: 0.273765176607571.
# [I 2025-05-18 19:26:16,735] Trial 5 finished with value: 0.4005012875002904 and parameters: {'n_estimators': 38, 'max_depth': 12, 'learning_rate': 0.004273823690071297, 'min_samples_leaf': 8, 'subsample': 0.9504425662827845}. Best is trial 0 with value: 0.273765176607571.
# [I 2025-05-18 19:27:39,883] Trial 6 finished with value: 0.32071766309785105 and parameters: {'n_estimators': 25, 'max_depth': 16, 'learning_rate': 0.03177401840797005, 'min_samples_leaf': 15, 'subsample': 0.7484817202850274}. Best is trial 0 with value: 0.273765176607571.
# [I 2025-05-18 19:31:01,651] Trial 7 finished with value: 0.3740199594021853 and parameters: {'n_estimators': 69, 'max_depth': 12, 'learning_rate': 0.00479957713815171, 'min_samples_leaf': 13, 'subsample': 0.7445214473742678}. Best is trial 0 with value: 0.273765176607571.
# [I 2025-05-18 19:31:48,233] Trial 8 finished with value: 0.40643356986546525 and parameters: {'n_estimators': 12, 'max_depth': 15, 'learning_rate': 0.010845737777663787, 'min_samples_leaf': 18, 'subsample': 0.9142060285071777}. Best is trial 0 with value: 0.273765176607571.
# [I 2025-05-18 19:33:18,193] Trial 9 finished with value: 0.3567061940003003 and parameters: {'n_estimators': 24, 'max_depth': 8, 'learning_rate': 0.020398554539350754, 'min_samples_leaf': 8, 'subsample': 0.9053379208630539}. Best is trial 0 with value: 0.273765176607571.
# Mejores hiperparámetros encontrados:
# {'n_estimators': 142, 'max_depth': 7, 'learning_rate': 0.019889634195779663, 'min_samples_leaf': 6, 'subsample': 0.9650245722935478}

# %%
final_model = GradientBoostingRegressor(n_estimators=142, max_depth=7, learning_rate=0.019889634195779663, min_samples_leaf=6, subsample=0.9650245722935478, loss="quantile", alpha=0.5)
final_model.fit(X_filtered, y_filtered.flatten())
# Out:
# GradientBoostingRegressor(alpha=0.5, learning_rate=0.019889634195779663,
#                           loss='quantile', max_depth=7, min_samples_leaf=6,
#                           n_estimators=142, subsample=0.9650245722935478)

# %%
y_hat_scaled = final_model.predict(X_test_filtered)

# %%
y_hat = preprocessor.inverse_transform(y_hat_scaled.reshape(-1,1))
# Out:
# c:\Users\marti\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but QuantileTransformer was fitted with feature names
#   warnings.warn(

# %%
from sklearn.metrics import mean_pinball_loss

# Predecimos en test
y_test_pred = final_model.predict(X_test_filtered)

# Calculamos la pérdida de Pinball
test_loss = mean_pinball_loss(y_test_filtered, y_test_pred, alpha=0.5)

# Formateamos y mostramos resultados con interpretación
print("\nModel Performance Metric:\n")
print(f"{'Metric':<20} {'Value':>10}")
print("-" * 30)
print(f"{'Pinball Loss':<20} {test_loss:>10.4f}")

print("\nInterpretation:")
print(f"- Pinball Loss (α = {0.5}): measures the error specific to quantile regression.")
print(f"- A lower value indicates better accuracy at estimating the {int(0.5 * 100)}th percentile.")
# Out:
# Model Performance Metric:
#
# Metric                    Value
# ------------------------------
# Pinball Loss             0.2781
#
# Interpretation:
# - Pinball Loss (α = 0.5): measures the error specific to quantile regression.
# - A lower value indicates better accuracy at estimating the 50th percentile.
